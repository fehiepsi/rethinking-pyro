# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import torch

import pyro
import pyro.distributions as dist

from rethinking import HPDI, MAP

# %% [markdown]
# #### Code 4.1

# %%
pos = torch.empty(1000, 16).uniform_(-1, 1).sum(1)

# %% [markdown]
# #### Code 4.2

# %%
(1 + torch.empty(12).uniform_(0, 0.1)).prod()
# Out:
# tensor(1.8197)

# %% [markdown]
# #### Code 4.3

# %%
growth = (1 + torch.empty(10000, 12).uniform_(0, 0.1)).prod(1)
pd.Series(growth).plot(kind="density");

# %% [markdown]
# #### Code 4.4

# %%
big = (1 + torch.empty(10000, 12).uniform_(0, 0.5)).prod(1)
small = (1 + torch.empty(10000, 12).uniform_(0, 0.01)).prod(1)

# %% [markdown]
# #### Code 4.5

# %%
log_big = (1 + torch.empty(10000, 12).uniform_(0, 0.5)).prod(1).log()

# %% [markdown]
# #### Code 4.6

# %%
w, n = 6., 9
p_grid = torch.linspace(start=0, end=1, steps=1000)
posterior = (dist.Binomial(n, p_grid).log_prob(torch.tensor(w)).exp()
             * dist.Uniform(0, 1).log_prob(p_grid).exp())
posterior = posterior / sum(posterior)

# %% [markdown]
# #### Code 4.7

# %%
howell1 = pd.read_csv("data/Howell1.csv", sep=";")
d = howell1

# %% [markdown]
# #### Code 4.8

# %%
print(d.info())
print(d.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 544 entries, 0 to 543
# Data columns (total 4 columns):
# height    544 non-null float64
# weight    544 non-null float64
# age       544 non-null float64
# male      544 non-null int64
# dtypes: float64(3), int64(1)
# memory usage: 17.1 KB
# None
#     height     weight   age  male
# 0  151.765  47.825606  63.0     1
# 1  139.700  36.485807  63.0     0
# 2  136.525  31.864838  65.0     0
# 3  156.845  53.041915  41.0     1
# 4  145.415  41.276872  51.0     0

# %% [markdown]
# #### Code 4.9

# %%
d.height.head()
# Out:
# 0    151.765
# 1    139.700
# 2    136.525
# 3    156.845
# 4    145.415
# Name: height, dtype: float64

# %% [markdown]
# #### Code 4.10

# %%
d2 = d[d.age >= 18]

# %% [markdown]
# #### Code 4.11

# %%
x = torch.linspace(100, 250, 101)
plt.plot(x.numpy(), dist.Normal(178, 20).log_prob(x).exp().numpy());

# %% [markdown]
# #### Code 4.12

# %%
x = torch.linspace(-10, 60, 101)
plt.plot(x.numpy(), dist.Uniform(0, 50).log_prob(x).exp().numpy());

# %% [markdown]
# #### Code 4.13

# %%
sample_mu = dist.Normal(178, 20).sample(torch.Size([int(1e4)]))
sample_sigma = dist.Uniform(0, 50).sample(torch.Size([int(1e4)]))
prior_h = dist.Normal(sample_mu, sample_sigma).sample()
pd.Series(prior_h).plot(kind="density", xlim=(28, 328));

# %% [markdown]
# #### Code 4.14

# %%
mu_list = torch.linspace(start=140, end=160, steps=200)
sigma_list = torch.linspace(start=4, end=9, steps=200)
post = {"mu": mu_list.expand(200, 200).reshape(-1),
        "sigma": sigma_list.expand(200, 200).t().reshape(-1)}
post_LL = dist.Normal(post["mu"], post["sigma"]).log_prob(
    torch.tensor(d2.height.values, dtype=torch.float).unsqueeze(1)).sum(0)
post_prod = (post_LL + dist.Normal(178, 20).log_prob(post["mu"])
             + dist.Uniform(0, 50).log_prob(post["sigma"]))
post_prob = (post_prod - max(post_prod)).exp()

# %% [markdown]
# #### Code 4.15

# %%
plt.contour(post["mu"].reshape(200, 200).numpy(),
            post["sigma"].reshape(200, 200).numpy(),
            post_prob.reshape(200, 200).numpy());

# %% [markdown]
# #### Code 4.16

# %%
plt.imshow(post_prob.reshape(200, 200).numpy(), aspect="auto",
           origin="lower", extent=(140, 160, 4, 9));

# %% [markdown]
# #### Code 4.17

# %%
sample_rows = torch.multinomial(input=post_prob, num_samples=int(1e4),
                                replacement=True)
sample_mu = post["mu"][sample_rows]
sample_sigma = post["sigma"][sample_rows]

# %% [markdown]
# #### Code 4.18

# %%
plt.plot(sample_mu.numpy(), sample_sigma.numpy(), "o", markersize=3, 
         c="royalblue", alpha=0.1)
plt.xlabel("sample.mu")
plt.ylabel("sample.sigma");

# %% [markdown]
# #### Code 4.19

# %%
pd.Series(sample_mu).plot(kind="density", xlim=(153, 156.5))
plt.show()
pd.Series(sample_sigma).plot(kind="density", xlim=(6.5, 9));

# %% [markdown]
# #### Code 4.20

# %%
print(HPDI(sample_mu))
print(HPDI(sample_sigma))
# Out:
# tensor([153.8694, 155.1759])
# tensor([7.3668, 8.2965])

# %% [markdown]
# #### Code 4.21

# %%
d3 = torch.tensor(d2.height.sample(n=20).values, dtype=torch.float)

# %% [markdown]
# #### Code 4.22

# %%
mu_list = torch.linspace(start=150, end=170, steps=200)
sigma_list = torch.linspace(start=4, end=20, steps=200)
post2 = {"mu": mu_list.expand(200, 200).reshape(-1),
         "sigma": sigma_list.expand(200, 200).t().reshape(-1)}
post2_LL = dist.Normal(post2["mu"], post2["sigma"]).log_prob(d3.unsqueeze(1)).sum(0)
post2_prod = (post2_LL + dist.Normal(178, 20).log_prob(post2["mu"])
              + dist.Uniform(0, 50).log_prob(post2["sigma"]))
post2_prob = (post2_prod - max(post2_prod)).exp()
sample2_rows = torch.multinomial(input=post2_prob, num_samples=int(1e4),
                                 replacement=True)
sample2_mu = post2["mu"][sample2_rows]
sample2_sigma = post2["sigma"][sample2_rows]
plt.plot(sample2_mu.numpy(), sample2_sigma.numpy(), "o", markersize=3, 
         c="royalblue", alpha=0.1)
plt.xlabel("mu")
plt.ylabel("sigma");

# %% [markdown]
# #### Code 4.23

# %%
pd.Series(sample2_sigma).plot(kind="density", xlim=(4, 20));
x = torch.linspace(4, 20, 101)
plt.plot(x.numpy(), dist.Normal(sample2_sigma.mean(),
                                sample2_sigma.std()).log_prob(x).exp().numpy(), "--");

# %% [markdown]
# #### Code 4.24

# %%
howell1 = pd.read_csv("data/Howell1.csv", sep=";")
d = howell1
d2 = d[d.age >= 18]
d2_height = torch.tensor(d2.height.values, dtype=torch.float)

# %% [markdown]
# #### Code 4.25

# %%
def flist(height):
    mu = pyro.sample("mu", dist.Normal(178, 20))
    sigma = pyro.sample("sigma", dist.Uniform(0, 50))
    pyro.sample("height", dist.Normal(mu, sigma), obs=height)

# %% [markdown]
# #### Code 4.26

# %%
m4_1 = MAP(flist, height=d2_height)
m4_1.fit();

# %% [markdown]
# #### Code 4.27

# %%
m4_1.precis()
# Out:
#          Mean  StdDev    5.5%   94.5%
# mu     154.61    0.41  153.95  155.27
# sigma    7.73    0.29    7.27    8.20

# %% [markdown]
# #### Code 4.28

# %%
start = {"mu": d2_height.mean(), "sigma": d2_height.std()}

# %% [markdown]
# #### Code 4.29

# %%
def m4_2_model(height):
    mu = pyro.sample("mu", dist.Normal(178, 0.1))
    sigma = pyro.sample("sigma", dist.Uniform(0, 50))
    pyro.sample("height", dist.Normal(mu, sigma), obs=height)

m4_2 = MAP(m4_2_model, name="m4_2", height=d2_height)
m4_2.fit()
m4_2.precis()
# Out:
#          Mean  StdDev    5.5%   94.5%
# mu     177.86    0.10  177.70  178.02
# sigma   24.52    0.93   23.03   26.00

# %% [markdown]
# #### Code 4.30

# %%
m4_1.vcov()
# Out:
# tensor([[0.1697, 0.0002],
#         [0.0002, 0.0849]])

# %% [markdown]
# #### Code 4.31

# %%
cov = m4_1.vcov()
print(cov.diag())
sd = cov.diag().sqrt()
print(cov / (sd.unsqueeze(1) * sd))
# Out:
# tensor([0.1697, 0.0849])
# tensor([[1.0000, 0.0018],
#         [0.0018, 1.0000]])

# %% [markdown]
# #### Code 4.32

# %%
post = m4_1.extract_samples(n=int(1e4))
{latent: post[latent][:6] for latent in post}
# Out:
# {'mu': tensor([154.9189, 154.2060, 155.0625, 154.0781, 154.3508, 155.0762]),
#  'sigma': tensor([7.9170, 7.5984, 7.8678, 7.8480, 7.8449, 7.5720])}

# %% [markdown]
# #### Code 4.33

# %%
mean, std_dev, hpd_left, hpd_right = {}, {}, {}, {}
for latent in post:
    mean[latent] = post[latent].mean().numpy()
    std_dev[latent] = post[latent].std().numpy()
    hpdi = HPDI(post[latent], prob=0.89)
    hpd_left[latent] = hpdi[0].numpy()
    hpd_right[latent] = hpdi[1].numpy()
pd.DataFrame.from_dict({"Mean": mean, "StdDev": std_dev, "|0.89": hpd_left,
                        "0.89|": hpd_right}).astype("float").round(2)
# Out:
#          Mean  StdDev   |0.89   0.89|
# mu     154.61    0.41  153.95  155.25
# sigma    7.73    0.29    7.27    8.20

# %% [markdown]
# #### Code 4.34

# %%
post = dist.MultivariateNormal(
    loc=m4_1.coef(), covariance_matrix=m4_1.vcov()).sample(torch.Size([int(1e4)]))

# %% [markdown]
# #### Code 4.35

# %%
def m4_1_logsigma_model(height):
    mu = pyro.sample("mu", dist.Normal(178, 20))
    log_sigma = pyro.sample("log_sigma", dist.Normal(2, 10))
    pyro.sample("height", dist.Normal(mu, log_sigma.exp()), obs=height)

m4_1_logsigma = MAP(m4_1_logsigma_model, name="m4_1_logsigma_model",
                    height=d2_height)
pyro.set_rng_seed(2)
m4_1_logsigma.fit();

# %% [markdown]
# #### Code 4.36

# %%
post = m4_1_logsigma.extract_samples()
sigma = post["log_sigma"].exp()

# %% [markdown]
# #### Code 4.37

# %%
plt.plot(d2.weight, d2.height, "o");

# %% [markdown]
# #### Code 4.38

# %%
# load data again, since it's a long way back
howell1 = pd.read_csv("data/Howell1.csv", sep=";")
d = howell1
d2 = d[d.age >= 18]
d2_weight = torch.tensor(d2.weight.values, dtype=torch.float)
d2_height = torch.tensor(d2.height.values, dtype=torch.float)

def m4_3_model(weight, height):
    a = pyro.sample("a", dist.Normal(178, 100))
    b = pyro.sample("b", dist.Normal(0, 10))
    mu = a + b * weight
    sigma = pyro.sample("sigma", dist.Uniform(0, 50))
    pyro.sample("height", dist.Normal(mu, sigma), obs=height)

# fit model
m4_3 = MAP(m4_3_model, name="m4_3", weight=d2_weight, height=d2_height)
pyro.set_rng_seed(2)
m4_3.fit(lr=0.5);

# %% [markdown]
# #### Code 4.39

# %%
def m4_3_nomu_model(weight, height):
    a = pyro.sample("a", dist.Normal(178, 100))
    b = pyro.sample("b", dist.Normal(0, 10))
    sigma = pyro.sample("sigma", dist.Uniform(0, 50))
    pyro.sample("height", dist.Normal(a + b * weight, sigma), obs=height)

m4_3_nomu = MAP(m4_3_nomu_model, name="m4_3_nomu", weight=d2_weight, height=d2_height)
pyro.set_rng_seed(2)
m4_3_nomu.fit(lr=0.5);

# %% [markdown]
# #### Code 4.40

# %%
m4_3.precis()
# Out:
#          Mean  StdDev    5.5%   94.5%
# a      113.90    1.91  110.86  116.95
# b        0.90    0.04    0.84    0.97
# sigma    5.07    0.19    4.77    5.38

# %% [markdown]
# #### Code 4.41

# %%
m4_3.precis(corr=True)
# Out:
#          Mean  StdDev    5.5%   94.5%     a     b  sigma
# a      113.90    1.91  110.86  116.95  1.00 -0.99    0.0
# b        0.90    0.04    0.84    0.97 -0.99  1.00   -0.0
# sigma    5.07    0.19    4.77    5.38  0.00 -0.00    1.0

# %% [markdown]
# #### Code 4.42

# %%
d2_weight_c = d2_weight - d2_weight.mean()

# %% [markdown]
# #### Code 4.43

# %%
m4_4 = MAP(m4_3_model, name="m4_4", weight=d2_weight_c, height=d2_height)
pyro.set_rng_seed(2)
m4_4.fit();

# %% [markdown]
# #### Code 4.44

# %%
m4_4.precis(corr=True)
# Out:
#          Mean  StdDev    5.5%   94.5%    a    b  sigma
# a      154.61    2.66  150.36  158.87  1.0  0.0    NaN
# b        0.90    0.41    0.24    1.56  0.0  1.0    NaN
# sigma   50.00     NaN     NaN     NaN  NaN  NaN    NaN

# %% [markdown]
# #### Code 4.45

# %%
plt.plot(d2.weight, d2.height, "o", fillstyle="none")
plt.xlabel("weight")
plt.ylabel("height")
x = torch.linspace(30, 65, 101)
plt.plot(x.numpy(), (m4_3.coef()[0] + m4_3.coef()[1] * x).numpy());

# %% [markdown]
# #### Code 4.46

# %%
post = m4_3.extract_samples()

# %% [markdown]
# #### Code 4.47

# %%
{latent: post[latent][:5] for latent in post}
# Out:
# {'a': tensor([116.1288, 113.2759, 116.2391, 113.4755, 114.5329]),
#  'b': tensor([0.8497, 0.9187, 0.8595, 0.9113, 0.8980]),
#  'sigma': tensor([5.0494, 4.9841, 4.9282, 4.8157, 5.0436])}

# %% [markdown]
# #### Code 4.48

# %%
N = 10
dN = {"weight": d2_weight[:N], "height": d2_height[:N]}
mN = MAP(m4_3_model, name="mN", **dN)
pyro.set_rng_seed(2)
mN.fit(lr=0.5);

# %% [markdown]
# #### Code 4.49

# %%
# extract 20 samples from the posterior
post = mN.extract_samples(n=20)

# display raw data and sample size
plt.plot(dN["weight"].numpy(), dN["height"].numpy(), "o", fillstyle="none")
plt.xlabel("weight")
plt.ylabel("height")
plt.title("N = {}".format(N))

# plot the lines, with transparency
x = torch.linspace(30, 65, 101)
for i in range(20):
    plt.plot(x.numpy(), (post["a"][i] + post["b"][i] * x).numpy(), c="k", alpha=0.3);

# %% [markdown]
# #### Code 4.50

# %%
post = m4_3.extract_samples()
mu_at_50 = post["a"] + post["b"] * 50

# %% [markdown]
# #### Code 4.51

# %%
pd.Series(mu_at_50).plot(kind="density", c="royalblue",
                         linewidth=2, xlim=(157.5, 160.5))
plt.xlabel("mu|weight=50");

# %% [markdown]
# #### Code 4.52

# %%
HPDI(mu_at_50, prob=0.89)
# Out:
# tensor([158.5731, 159.6580])

# %% [markdown]
# #### Code 4.53

# %%
mu = m4_3.link()
mu.shape, mu[:5, 0]
# Out:
# (torch.Size([1000, 352]),
#  tensor([157.3701, 157.0760, 156.9592, 157.2255, 157.4920]))

# %% [markdown]
# #### Code 4.54

# %%
# define sequence of weights to compute predictions for
# these values will be on the horizontal axis
weight_seq = torch.arange(start=25, end=71, step=1.)

# use link to compute mu
# for each sample from posterior
# and for each weight in weight_seq
mu = m4_3.link(weight=weight_seq)
mu.shape, mu[:5, 0]
# Out:
# (torch.Size([1000, 46]),
#  tensor([136.6077, 138.0218, 137.5877, 136.7534, 135.9654]))

# %% [markdown]
# #### Code 4.55

# %%
# use visible=False to hide raw data
plt.plot("weight", "height", "o", data=d2, visible=False)
plt.xlabel("weight")
plt.ylabel("height")

# loop over samples and plot each mu value
for i in range(100):
    plt.plot(weight_seq.numpy(), mu[i, :].numpy(), "o", c="royalblue", alpha=0.1)

# %% [markdown]
# #### Code 4.56

# %%
# summarize the distribution of mu
mu_mean = mu.mean(0)
mu_HPDI = HPDI(mu, 0, prob=0.89)

# %% [markdown]
# #### Code 4.57

# %%
# plot raw data
# fading out points to make line and interval more visible
plt.plot("weight", "height", "o", data=d2, c="royalblue", alpha=0.5)
plt.xlabel("weight")
plt.ylabel("height")

# plot the MAP line, aka the mean mu for each weight
plt.plot(weight_seq.numpy(), mu_mean.numpy())

# plot a shaded region for 89% HPDI
plt.fill_between(weight_seq.numpy(), mu_HPDI[0, :].numpy(), mu_HPDI[1, :].numpy(),
                 color="black", alpha=0.15);

# %% [markdown]
# #### Code 4.58

# %%
post = m4_3.extract_samples()
mu_link = lambda weight: post["a"].unsqueeze(1) + post["b"].unsqueeze(1) * weight
weight_seq = torch.arange(start=25, end=71, step=1.)
mu = mu_link(weight_seq)
mu_mean = mu.mean(0)
mu_HPDI = HPDI(mu, 0, prob=0.89)

# %% [markdown]
# #### Code 4.59

# %%
sim_height = m4_3.sim(weight=weight_seq)
sim_height.shape, sim_height[:5, 0]
# Out:
# (torch.Size([1000, 46]),
#  tensor([137.4272, 137.7048, 131.3336, 138.2670, 139.3289]))

# %% [markdown]
# #### Code 4.60

# %%
prob = 0.89
height_PI = pd.DataFrame(sim_height.numpy()).quantile(
    [(1 - prob) / 2, (1 + prob) / 2], 0)

# %% [markdown]
# #### Code 4.61

# %%
# plot raw data
plt.plot("weight", "height", "o", data=d2, c="royalblue", alpha=0.5)
plt.xlabel("weight")
plt.ylabel("height")

# draw MAP line
plt.plot(weight_seq.numpy(), mu_mean.numpy())

# draw HPDI region for line
plt.fill_between(weight_seq.numpy(), mu_HPDI[0, :].numpy(), mu_HPDI[1, :].numpy(),
                 color="black", alpha=0.15)

# draw PI region for simulated heights
plt.fill_between(weight_seq.numpy(), height_PI.iloc[0, :], height_PI.iloc[1, :],
                 color="black", alpha=0.15);

# %% [markdown]
# #### Code 4.62

# %%
sim_height = m4_3.sim(weight=weight_seq, n=int(1e4))
prob = 0.89
height_PI = pd.DataFrame(sim_height.numpy()).quantile(
    [(1 - prob) / 2, (1 + prob) / 2], 0)

# %% [markdown]
# #### Code 4.63

# %%
post = m4_3.extract_samples()
weight_seq = torch.arange(start=25, end=71, step=1.)
def sim(weight):
    mean = post["a"].unsqueeze(1) + post["b"].unsqueeze(1) * weight
    sd = post["sigma"].unsqueeze(1)
    return dist.Normal(loc=mean, scale=sd).sample()

sim_height = sim(weight_seq)
prob = 0.89
height_PI = pd.DataFrame(sim_height.numpy()).quantile(
    [(1 - prob) / 2, (1 + prob) / 2], 0)

# %% [markdown]
# #### Code 4.64

# %%
howell1 = pd.read_csv("data/Howell1.csv", sep=";")
d = howell1
d_height = torch.tensor(d.height, dtype=torch.float)
print(d.info())
print(d.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 544 entries, 0 to 543
# Data columns (total 4 columns):
# height    544 non-null float64
# weight    544 non-null float64
# age       544 non-null float64
# male      544 non-null int64
# dtypes: float64(3), int64(1)
# memory usage: 17.1 KB
# None
#     height     weight   age  male
# 0  151.765  47.825606  63.0     1
# 1  139.700  36.485807  63.0     0
# 2  136.525  31.864838  65.0     0
# 3  156.845  53.041915  41.0     1
# 4  145.415  41.276872  51.0     0

# %% [markdown]
# #### Code 4.65

# %%
d_weight_s = torch.tensor((d.weight - d.weight.mean()) / d.weight.std(),
                          dtype=torch.float)

# %% [markdown]
# #### Code 4.66

# %%
d_weight_s2 = d_weight_s ** 2

def m4_5_model(weight_s, weight_s2, height):
    a = pyro.sample("a", dist.Normal(178, 100))
    b1 = pyro.sample("b1", dist.Normal(0, 10))
    b2 = pyro.sample("b2", dist.Normal(0, 10))
    mu = a + b1 * weight_s + b2 * weight_s2
    sigma = pyro.sample("sigma", dist.Uniform(0, 50))
    pyro.sample("height", dist.Normal(mu, sigma), obs=height)

m4_5 = MAP(m4_5_model, name="m4_5", weight_s=d_weight_s, weight_s2=d_weight_s2,
           height=d_height)
pyro.set_rng_seed(2)
m4_5.fit(lr=0.5);

# %% [markdown]
# #### Code 4.67

# %%
m4_5.precis()
# Out:
#          Mean  StdDev    5.5%   94.5%
# a      146.66    0.37  146.07  147.26
# b1      21.40    0.29   20.94   21.86
# b2      -8.42    0.28   -8.86   -7.97
# sigma    5.75    0.17    5.47    6.03

# %% [markdown]
# #### Code 4.68

# %%
weight_seq = torch.linspace(start=-2.2, end=2, steps=30)
pred_data = {"weight_s": weight_seq, "weight_s2": weight_seq ** 2}
mu = m4_5.link(**pred_data)
mu_mean = mu.mean(0)
prob=0.89
mu_PI = pd.DataFrame(mu.numpy()).quantile([(1 - prob) / 2, (1 + prob) / 2], 0)
sim_height = m4_5.sim(**pred_data)
height_PI = pd.DataFrame(sim_height.numpy()).quantile(
    [(1 - prob) / 2, (1 + prob) / 2], 0)

# %% [markdown]
# #### Code 4.69

# %%
plt.plot(d_weight_s.numpy(), d.height, "o", c="royalblue", alpha=0.5)
plt.xlabel("weight")
plt.ylabel("height")
plt.plot(weight_seq.numpy(), mu_mean.numpy())
plt.fill_between(weight_seq.numpy(), mu_PI.iloc[0, :], mu_PI.iloc[1, :],
                 color="black", alpha=0.15)
plt.fill_between(weight_seq.numpy(), height_PI.iloc[0, :], height_PI.iloc[1, :],
                 color="black", alpha=0.15);

# %% [markdown]
# #### Code 4.70

# %%
d_weight_s3 = d_weight_s ** 3

def m4_6_model(weight_s, weight_s2, weight_s3, height):
    a = pyro.sample("a", dist.Normal(178, 100))
    b1 = pyro.sample("b1", dist.Normal(0, 10))
    b2 = pyro.sample("b2", dist.Normal(0, 10))
    b3 = pyro.sample("b3", dist.Normal(0, 10))
    mu = a + b1 * weight_s + b2 * weight_s2 + b3 * weight_s3
    sigma = pyro.sample("sigma", dist.Uniform(0, 50))
    pyro.sample("height", dist.Normal(mu, sigma), obs=height)

m4_6 = MAP(m4_6_model, name="m4_6", weight_s=d_weight_s, weight_s2=d_weight_s2,
           weight_s3=d_weight_s3, height=d_height)
pyro.set_rng_seed(2)
m4_6.fit();

# %% [markdown]
# #### Code 4.71

# %%
fig, ax = plt.subplots()
ax.plot(d_weight_s.numpy(), d.height, "o", color="royalblue", alpha=0.5)
ax.set_xticks([]);

# %% [markdown]
# #### Code 4.72

# %%
at = torch.tensor([-2, -1, 0, 1, 2])
labels = at * d.weight.std() + d.weight.mean()
ax.set_xticks(at.numpy())
ax.set_xticklabels(labels.numpy().round(1))
fig

# %% [markdown]
# #### Code 4.73

# %%
plt.plot("weight", "height", "o", data=howell1, color="royalblue", alpha=0.4);
